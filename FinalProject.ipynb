# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Text as Data

# %% [markdown]
# # Metadata
#
# - Full Name: Lino De Ros
# - Userid: xcm7zb
# - GitHub Repo URL: https://github.com/lderos/DS-5001-Final-Project
# - UVA Box URL: https://virginia.box.com/s/c8eq1i61whl6dek6izpngtyxpxw5z6oi

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# I am working on a comparative linguistic analysis of human vs. AI-generated text. My primary data source is the HC3 Dataset, which I obtained from the URL provided below. This dataset contains paired human and AI-generated responses to the same questions, drawn from platforms such as Reddit and StackExchange, and includes ChatGPT responses from 2023.
#
# To construct a consistent and comparable corpus, I restricted the dataset to a randomly selected subset of 2,000 questions. These same 2,000 questions are used across all three groups in the analysis: human responses, older AI responses (2023-era ChatGPT), and newer AI responses (ChatGPT 5.4-mini). This ensures that each group consists of responses to identical prompts, enabling direct comparison of linguistic patterns across generators.
#
# To generate the newer AI responses, each of the 2,000 selected questions was passed through a standardized prompt using the OpenAI API. The prompt used for every query was:
#
# “Answer the following question in a clear and concise paragraph, similar to how a knowledgeable person might respond online. Avoid bullet points and keep the explanation straightforward.”
#
# Each question was appended to this prompt and submitted to the gpt-5.4-mini model. The generation process was automated via a Python script that iterated through the selected questions and stored the resulting outputs in a structured CSV file. A maximum token limit was applied to maintain consistency in response length.
#
# This design results in a matched corpus of 2,000 prompts, each associated with one human response, one older AI response, and one newer AI response, allowing for controlled analysis of how AI-generated language has evolved over time.
#
# https://huggingface.co/datasets/Hello-SimpleAI/HC3/viewer/all/train

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://huggingface.co/datasets/Hello-SimpleAI/HC3/viewer/all/train
# - UVA Box URL: https://virginia.app.box.com/file/2201610167802 (human and AI Old) & https://virginia.app.box.com/file/2205736804049 (AI New)
# - Number of raw documents: 2 (`all.jsonl` and `chatgptNew_filled.csv`)
# - Total size of raw documents (e.g. in MB): 72.0 MB
# - File format(s), e.g. XML, plaintext, etc.: .jsonl and .csv

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# 1. `all.jsonl`: Consists of 24,321 rows. Each document corresponds to a single question–response set. It includes a `question` field containing the prompt text, a `human_answers` field consisting of a list of one or more human-generated responses, a `chatgpt_answers` field containing one or more AI-generated responses (from an earlier model version), and a `source` field indicating the origin of the question (e.g., Reddit or StackExchange). The structure is hierarchical, with the question serving as the root and multiple associated answers grouped beneath it.
# 2. `chatgptNew_filled.csv`: Each document represents a single question selected from the original dataset. It includes a `Question_ID` field serving as a unique identifier, a `Question` field containing the text, and `ChatGPT_New field`, which contains a newly generated AI response for the corresponding question. The structure is flat and tabular, where each row links a unique question to its newly generated answer, enabling direct comparison with both human and earlier AI responses.

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205732656470
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/parser.ipynb
# - Delimitter: |
# - Number of observations: 5,967
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.): 'doc_id', 'Question_ID', 'Source', 'Group', 'char_count', 'token_count'
# - Average length of each document in characters: 840.56

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205734884636
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/parser.ipynb
# - Delimitter: |
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 867,643
# - OHCO Structure (as delimitted column names): doc_id|token_id
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`): 'doc_id', 'token_id', 'Question_ID', 'Source', 'Group', 'token_str', 'term_str', 'pos', 'pos_group'

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205736727146
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/parser.ipynb
# - Delimitter: |
# - Number of observations: 25,651
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`): 'term_str', 'n', 'max_pos', 'max_pos_group', 'p', 'i', 'df', 'dfidf', 'porter_stem', 'stop'
# - List the top 20 significant words in the corpus by DFIDF.
#
# (INSERT LIST HERE)

# %%
import pandas as pd

VOCAB = pd.read_csv("VOCAB.csv", sep="|")

top20_dfidf = (
    VOCAB[
        (VOCAB["stop"] == False) &
        (VOCAB["term_str"].str.len() > 1)
    ]
    .sort_values("dfidf", ascending=False)[["term_str", "dfidf"]]
    .head(20)
)

top20_dfidf
# Out:
#         term_str         dfidf
# 671         also  17973.914640
# 12862       like  17486.999830
# 16456     people  13177.238521
# 13412       make  12997.043836
# 15541        one  12786.566535
# 13694        may  12578.372093
# 24943        way  11468.439623
# 23163       time  11464.925614
# 24345    usually  11015.228267
# 13515       many  10799.940135
# 24310        use  10435.238076
# 7697        even   9853.900729
# 15483      often   9688.363891
# 9448         get   9670.559933
# 11035  important   9418.558479
# 6076   different   9000.869756
# 15261         nt   8995.875313
# 10255       help   8701.643985
# 14526       much   8692.429165
# 24312       used   7901.796930

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL: https://virginia.app.box.com/folder/377338136960?s=c8eq1i61whl6dek6izpngtyxpxw5z6oi
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/derivedTables.ipynb
# - Delimitter: |
# - Bag (expressed in terms of OHCO levels): 'doc_id'
# - Number of observations: 326,807
# - Columns (as delimitted names, including `n`, `tfidf`): 'doc_id', 'term_str', 'n', 'tfidf'

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205767118379
# - UVA Box URL of BOW used to generate (if applicable): https://virginia.app.box.com/file/2205749714003
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/derivedTables.ipynb
# - Delimitter: |
# - Bag (expressed in terms of OHCO levels): 'doc_id'

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205760688611
# - UVA Box URL of DTM or BOW used to create: https://virginia.app.box.com/file/2205767118379
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/derivedTables.ipynb
# - Delimitter: |
# - Description of TFIDIF formula ($\LaTeX$ OK):
#
# For each document $d$ and term $t$, the TFIDF weight is computed as:
#
# $$
# \mathrm{tfidf}(t,d) = \mathrm{tf}(t,d) \cdot \log_2\left(\frac{D}{\mathrm{df}(t)}\right)
# $$
#
# where $\mathrm{tf}(t,d)$ is the raw frequency of term $t$ in document $d$, $D$ is the total number of documents in the corpus, and $\mathrm{df}(t)$ is the number of documents containing term $t$.

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL: https://virginia.app.box.com/file/2205781862131
# - UVA Box URL of source TFIDF table: https://virginia.app.box.com/file/2205760688611
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/derivedTables.ipynb
# - Delimitter: |
# - Number of features (i.e. significant words): 25,262
# - Principle of significant word selection: Significant words were defined as terms with document frequency of at least 5. This threshold removes extremely rare terms that contribute little to corpus-wide comparison while preserving words that recur across multiple documents.

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL:
# - UVA Box URL of the source TFIDF_L2 table: https://virginia.app.box.com/file/2205781862131
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter: |
# - Number of components:  10
# - Library used to generate: scikit-learn TruncatedSVD
# - Top 5 positive terms for first component: 'people' 'like' 'may' 'money' 'make'
# - Top 5 negative terms for second component: 'body' 'water' 'like' 'brain' 'feel'

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter: |

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter: |

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Briefly describe the nature of the polarity you see in the first component:
#
# PC1 reflects a gradient from documents with low overall signal (generic or sparse term usage) to documents with high concentrations of dominant, distinguishing terms. Rather than separating two opposing topics, it measures degree of term prominence or document intensity.

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Briefly describe the nature of the polarity you see in the second component:
#
# PC4 exhibits a balanced polarity, separating documents into two opposing patterns of term usage. Documents with positive PC4 values emphasize one subset of terms, while those with negative values emphasize another. However, compared to earlier components, this polarity is weaker and more localized, reflecting finer-grained variation in the data rather than a dominant thematic split.

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL:
# - UVA Box URL of count matrix used to create:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:
# - Libary used to compute:
# - A description of any filtering, e.g. POS (Nouns and Verbs only):
# - Number of components:
# - Any other parameters used:
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00:
#   - T01:
#   - T02:
#   - T03:
#   - T04:

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the THETA table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL:
# - UVA Box URL for source lexicon:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:
# - Document bag expressed in terms of OHCO levels:

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# (INSERT IMAGE HERE)

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create: https://github.com/lderos/DS-5001-Final-Project/blob/main/models.ipynb
# - Delimitter:
# - Document bag expressed in terms of OHCO levels:
# - Number of features generated:
# - The library used to generate the embeddings:

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
# (INSERT IMAGE HERE)
#
# (INSERT DESCRIPTION HERE)

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# ## Riff 2 (5)
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# ## Riff 3 (5)
#
# (INSERT IMAGE HERE)
#
# (INSERT INTERPRETATION HERE)

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# (INSERT INTERPRETATION HERE)
